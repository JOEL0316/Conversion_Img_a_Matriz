# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
# Cargar la imagen
image = Image.open('dataset/ejemplo1.jpeg')

# %%
# Mostrar la imagen
plt.imshow(image)
plt.show()

# %%
# Convertir la imagen a una matriz de NumPy
image_array = np.array(image)

# %%
# Mostrar la forma de la matriz
print(image_array.shape)
# Out:
# (296, 474, 3)

# %%
# Imprimir la matriz
print(image_array)
# Out:
# [[[106  39  92]
#   [ 98  46  94]
#   [241 213 253]
#   ...
#   [  0   5  17]
#   [  0   5  17]
#   [  1   5  17]]
#
#  [[ 87  44  89]
#   [ 83  52  93]
#   [227 217 251]
#   ...
#   [  0   5  17]
#   [  0   6  18]
#   [  2   6  18]]
#
#  [[208 202 236]
#   [203 208 238]
#   [200 222 246]
#   ...
#   [  0   6  18]
#   [  1   7  19]
#   [  1   7  19]]
#
#  ...
#
#  [[ 33  41  28]
#   [ 23  31  18]
#   [ 13  24  10]
#   ...
#   [ 20  29   8]
#   [ 22  29  11]
#   [ 38  45  27]]
#
#  [[ 52  60  49]
#   [ 30  38  27]
#   [ 20  31  17]
#   ...
#   [ 17  26   7]
#   [ 40  47  29]
#   [ 68  75  57]]
#
#  [[ 55  63  52]
#   [ 25  33  22]
#   [ 18  26  15]
#   ...
#   [ 30  39  20]
#   [ 29  36  18]
#   [ 64  71  55]]]
